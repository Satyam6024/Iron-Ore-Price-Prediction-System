# %% [markdown]
# # 04 Feature Selection
#
# This notebook shows how the full engineered feature set is reduced before training.
#
# Current approach:
# - rank features using `random_forest_importance`
# - keep top `k` features
# - force-include core market features such as `Open`, `High`, `Low`, `Vol.`, and `Change %`

# %% [markdown]
# ## Research Paper Alignment
#
# Feature selection helps reduce model variance and keeps only strong predictive components, which supports hybrid ensemble stability.

# %%
from pathlib import Path
import json
import os
import subprocess
import sys
import yaml

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "params.yaml").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
os.chdir(PROJECT_ROOT)

def read_json(path: str):
    return json.loads(Path(path).read_text(encoding="utf-8"))

params = yaml.safe_load(Path("params.yaml").read_text(encoding="utf-8"))

# %%
params["feature_selection"]

# %%
subprocess.run([sys.executable, "dvc_pipeline/src/feature_selection.py"], check=True)

# %%
report = read_json(params["feature_selection"]["report_path"])
selected_columns = read_json(params["feature_selection"]["selected_columns_output_path"])
report, selected_columns
